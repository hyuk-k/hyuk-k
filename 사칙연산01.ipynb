# %% [markdown]
# # 파이썬에서 사칙 연산을 하려면 더하기 (+), 빼기(-), 곱하기(*), 나누기(/) 기호를 이용

# %%
1+1
# Out:
# 2

# %%
5-2
# Out:
# 3

# %% [markdown]
# # 파이썬에서는 숫자와 연산자 사이의 공백은 무시하므로 이 공백은 있어도 되고 없어도 됨

# %%
15*2
# Out:
# 30

# %%
10/2
# Out:
# 5.0

# %% [markdown]
# # 파이썬에서 나눗셈 연산은 실수로 처리

# %% [markdown]
# # 정수와 실수
#  - 정수: 자연수(1,2,3..)와 자연수의 음수 (-1,-2...), 그리고 0을 이뤄진 수의 집합
#  - 실수: 유리수와 무리수로 이뤄진 집합
#  - 프로그램에서는 숫자에 소수점이 없으면 정수(INT), 소수점이 있으면 실수 (FLOAT)

# %% [markdown]
# # 정수 연산만 할 수 있는 것이 아니라 실수 연산도 할 수 있음

# %%
1.2 + 5.3
# Out:
# 6.5

# %%
3.5-5.0
# Out:
# -1.5

# %%
1.4*2
# Out:
# 2.8

# %%
5/2
# Out:
# 2.5

# %% [markdown]
# # 연산 기호가 두개 이상일 경우 일반적인 연산 규칙 (괄호 안 계산 -> 지수 계산 -> 곱셈과 나눗셈 계산 -> 덧셈과 뺄셈 계산) 순서로 연산
# # 같은 순위의 연산일 경우 왼쪽에서 오른쪽 순서로 계산, 중복된 괄호가 있을 경우 안쪽 괄호부터 계산을 따름
# # 사칙연산 우선순위
#  1. () 괄호, 2. 지수계산, 3. 곱셈과 나눗셈, 4. 덧셈과 뺄

# %%
2+3*4
# Out:
# 14

# %%
3/2*4-5/2
# Out:
# 3.5

# %%
10/5+(5-2)*2
# Out:
# 8.0

# %%
(5*4-15)+((5-2)*(9-7))
# Out:
# 11

# %% [markdown]
# # 1. 선언 -> 2. 변수 선언 -> 3. 변수 대입 -> 4. 연산 -> 5. 연산 결과 출력
# #   (STD? OH -> INT A, FLOAT B; A=1, B=1.0, F=A+B, PRINT(F))

# %% [markdown]
# # 계산기 프로그램 (예제)
#  -  입력 값, 연산자 값 -> 처리 -> 결과 값 (화면, 파일)

# %% [markdown]
# # TYPE()함수
#  - 파이썬에서는 자료의 형식(데이터 타입)을 알려주는 TYPE()이라는 함수가 있음
#  - TYPE() 함수의 인자로 정수를 입력하면 INT를, 실수를 입력하면 FLOAT를 결과로 돌려줌
#  - TYPE() 함수에 정수와 실수를 입력

# %%
type (3)
# Out:
# int

# %%
type (1.2)
# Out:
# float

# %% [markdown]
# # 거듭 제곱
# - 숫자 A를 n번 곱하는 거듭제곱 (Power)
# - 파이썬에서는 거듭제곱을 위한 연산자 ** (두 별표 사이에는 공백이 없어야 함)
# - 정수 뿐만 아니라 실수도 거듭제곱

# %%
2*2*2*2*2
# Out:
# 32

# %%
2**5
# Out:
# 32

# %%
1.5**2
# Out:
# 2.25

# %% [markdown]
# # 거듭 제곱
# - 거듭제곱의 지수도 정수일 필요가 없음
# - 파이썬에서 제공하는 수학(math) 라이브러리를 이용하면 거듭제곱, 거듭제곱근 외에 다양한 수학 함수를 입력함

# %%
2** (1/2)
# Out:
# 1.4142135623730951

# %% [markdown]
# # 나머지
# - 나머지를 구하기 위해 파이썬에서는 퍼센트 기호(%)를 이용
# - 퍼센트 기호(%)를 나머지 연산자(modulo operator)라고 함
# - 몫은 정수 나누기 연산자(//)로 구할 수 있음

# %%
13%5
# Out:
# 3

# %%
13//5
# Out:
# 2

# %% [markdown]
# # 과학적 표기법
# - 연산할 때 아주 큰 수나 작은 수를 다뤄야 할 때 특히 과학이나 공학 분야
# - 거듭제곱 연산자로 큰 수 를 입력할 수 있지만 10의 거듭제곱 (즉, 10n)의 경우 en으로 편리하게 입력, 여기서 n은 정수로 양수, 음수, 0
# - 10의 거듭제곱 표시를 위한 en 앞에는 항상 숫자가 있어야 함

# %%
3*10**8
# Out:
# 300000000

# %%
3e8
# Out:
# 300000000.0

# %% [markdown]
# -  파이썬에서 과학적 표기법으로 출력할 떄는 e 다음에는 지수가 양수냐 음수냐에 따라서 양수 기호(+)나 음수 기호(-)가 들어감

# %%
1e15
# Out:
# 1000000000000000.0

# %%
1e16
# Out:
# 1e+16

# %%
1e-4
# Out:
# 0.0001

# %%
1e-5
# Out:
# 1e-05

# %% [markdown]
# # 진수 표현과 변환
# ## 과학적 표기법
# - 파이썬은 10진법 외에 2진법, 8진법, 16진법으로 숫자를 입출력하며 변화하는 방법을 제공
# - 10진수 외에 2진수, 8진수, 16진수를 입력하기 위해서는 숫자 앞에 각가 '0b','0o','0x'를 붙임

# %%
17
# Out:
# 17

# %%
0b10001
# Out:
# 17

# %%
0o021
# Out:
# 17

# %%
0x11
# Out:
# 17

# %% [markdown]
# - 파이썬에서는 2진수, 8진수, 16진수 형태로 숫자를 입력해도 기본적으로 10진수로 출력
# - 파이썬에서 10진수를 2진수, 8진수, 16진수로 변환하는 함수가 있고 각각의 함수는 bin(), oct(), hex()로 나타냄

# %%
bin(17)
# Out:
# '0b10001'

# %%
oct(17)
# Out:
# '0o21'

# %%
hex(17)
# Out:
# '0x11'

# %% [markdown]
# - 출력 결과는 숫자가 아니라 문자열임
# - 출력 결과는 작은 따옴표('') 안에 있음
# - 출력 결과가 숫자가 아니라 문자열임을 나타냄
# - bin(), oct(), hex() 함수를 이용한 출력 결과는 산술 연산에 이용할 수 없음
# - 진수 변환은 연산이 모두 끝난 후에 해야 함
# - 서로 다른 진수의 연산 결과를 10진수 2진수 8진수 16진수로 변화해 출력

# %%
0b10*0o10+0x10-10
# Out:
# 22

# %%
bin(0b10*0o10+0x10-10)
# Out:
# '0b10110'

# %%
oct(0b10*0o10+0x10-10)
# Out:
# '0o26'

# %%
hex(0b10*0o10+0x10-10)
# Out:
# '0x16'

# %% [markdown]
# # 논리연산 및 비교연산
# # 논리연산
#  - 어떤 조건을 만족하는 참(true)과 만족하지 않는 거짓(false)을 이용해 연산하는 논리 연산(logical operation), 논리 연산은 불린 연산(boolean operation)이라고도 함
#  - 파이썬에서 논리 연산을 위한 데이터 타입은 불(bool)임
#  - 불 데이터 타입에는 논리 참(true) 혹은 논리 거짓(false)이 있음
#  - 참(true) 혹인 거짓(false)을 입력할 때 참은 true, 거짓은 false를 입력

# %% [markdown]
# - 'true' 나 'False'처럼 따옴표를 사용하면 안됨
# - 따옴표를 이용해 입력하면 불 데이터가 아니라 문자열 데이터로 인식함
# - True를 true나 TRUE로 쓰거나 False 를 false 나 FALSE 로 쓸 수 없음

# %%
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %% [markdown]
# - 문자열을 출력하는 print('True')나 print('False')와 달리, 논리 연산의 결과를 출력한 것
# - 불 데이터인 True나 False의 데이터 타입은 type()함수를 이용해 확인

# %%
type(True)
# Out:
# bool

# %% [markdown]
# - 불 데이터의 경우 논리 연산만 할 수 잇음
# - 논리 연산에는 논리곱(and), 논리합(or), 논리 부정(not) 등
# - 논리곱(and)은 두 개의 불 데이터가 모두 참일떄만 참이고 나머지는 거짓
# - 논리합(or)은 두개의 불 데이터 중 하나라도 참이면 참이고 둘 다 거짓이면 거짓
# - 논리부정(not)은 하나의 불데이터가 참이면 거짓이고, 거짓이면 참

# %% [markdown]
# - 논리연산자
#
# ![논리연산자.PNG](data:image/png;base64,...)

# %% [markdown]
# - 논리연산자 진리표
#
# ![논리연산자 진리표.PNG](data:image/png;base64,...)

# %%
print(True and False)
# Out:
# False

# %%
print(True or False)
# Out:
# True

# %%
print(not True)
# Out:
# False

# %% [markdown]
# # 비교연산자
# -  두개의 숫자를 비교하는 비교 연산
#
# ![비교연산자.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 1. A=B (대입연산자) -> 치환
# ## 2. A==B (같다) => 비교연산자

# %% [markdown]
# - 비교 연산자를 이용해 연산
# - 비교 연산의 결과는 불 데이터 형식으로 나옴

# %%
print(5==3)
# Out:
# False

# %%
print(5!=3)
# Out:
# True

# %%
print(5<3)
# Out:
# False

# %%
print(5>3)
# Out:
# True

# %%
print(5<=3)
# Out:
# False

# %%
print(5>=3)
# Out:
# True

# %% [markdown]
# ## 논리 연산과 비교연산자 혼합연산
# - 비교 연산자의 우선순위가 논리 연자산의 우선순위보다 높음
# - 비교 연산자와 논리 연산자가 함께 있으면 비교 연산을 먼저 함

# %%
print(1>0 and -2<0)
# Out:
# True

# %% [markdown]
# - 비교 연산인 ' 1>0 과 '-2<0\을 먼저 수행하는데 결과는 모두 True
# - 그 후 이 연산의 결과를 이용해 논리곱{and} 연산을 수행하는데 결과는 True

# %% [markdown]
# - 괄호와 연산이 함께 있으면 괄호의 우선순위가 높음
# - 괄호가 여러겹 있을 때는 가장 안쪽 괄호부터 먼저 계산

# %%
print ((3<0)and ((-5>0)and(1>5)))
# Out:
# False

# %%
print ((3>0)or((-5>0)and(1>5)))
# Out:
# True

# %%
print(((3>0)or(-5>0)and((4>8)or(3<0))))
# Out:
# True
